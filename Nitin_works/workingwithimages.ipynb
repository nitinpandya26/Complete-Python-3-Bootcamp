# %%
from PIL import Image

# %%
mac = Image.open('example.jpg')

# %% [markdown]
# type(mac)

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
#CROPPING IMAGES

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FEFC8B87290>

# %%
pencils = Image.open('pencils.jpg')

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
x=0
y=1100
w=1950/3 
h=1300
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x200 at 0x7FEFC8BC31D0>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
halfway =1993/2

# %%
x=halfway-200
w=halfway+200

# %%
y=800
h=1257

# %%
comp = mac.crop((x,y,w,h))

# %%
mac.paste(im=comp,box=(0,0))

# %%
mac.resize((3000,500))
# Out:
# <PIL.Image.Image image mode=RGB size=3000x500 at 0x7FEFC8591A50>

# %%
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=1993x1257 at 0x7FEFC8BEE650>

# %%
red = Image.open('red_color.jpg')
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7FEFC8A45A50>

# %%
blue = Image.open('purple.png')
blue.putalpha(128)
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x7FEFC843FD90>

# %%
red = Image.open('red_color.jpg')
red.putalpha(128)
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x7FEFC8C679D0>

# %%
blue.paste(im=red,box=(0,0),mask=red )

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x7FEFC843FD90>

# %%
blue.save('pinkish.png')

# %%
pinkish =Image.open('pinkish.png')

# %%
pinkish
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x7FEFC8A539D0>

# %%
table= Image.open('word_matrix.png')
table.size
# Out:
# (1015, 559)

# %%
msk = Image.open('mask.png')
msk.size
nmsk = msk.resize((1015,559))

nmsk.size
#msk.putalpha(0)
#msk

#newtab.paste(im=msk,box=(0,0),mask=msk)
#newtab
# Out:
# (1015, 559)

# %%
nmsk.putalpha(200)

# %%
table.paste(nmsk,(0,0),nmsk)

# %%
table
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FEFC8AD3650>
